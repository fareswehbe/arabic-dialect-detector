# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import joblib

# %%
model_data = pd.read_csv('../data/test_models.csv')
model_data
# Out:
#       Model                                Performance Metrics  Accuracy
# 0  Logistic                precision    recall  f1-score   ...  0.425526
# 1        NB                precision    recall  f1-score   ...  0.433444
# 2       SVC                precision    recall  f1-score   ...  0.392632

# %%
plt.figure(figsize=(10, 6))
plt.bar(model_data['Model'], model_data['Accuracy'])
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('../data/figs/models_accuracy.png')
plt.show()
